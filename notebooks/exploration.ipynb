# %%
# notebooks/exploration.ipynb

# Import necessary libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import your custom functions
from src.data_preprocessing import load_and_preprocess_data
from src.model import build_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 import matplotlib.pyplot as plt
#       9 # Import your custom functions
# ---> 10 from src.data_preprocessing import load_and_preprocess_data
#      11 from src.model import build_model
#
# File ~\PycharmProjects\deadlift_predictive\src\data_preprocessing.py:4
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.preprocessing import StandardScaler
# ----> 4 from model import build_model
#       5 import tensorflow as tf
#       8 # load_and_preprocess_data function with updated file path
#
# ModuleNotFoundError: No module named 'model'

# %%
# Load the synthetic data (assumes you've generated it already)
data = pd.read_csv('../data/synthetic_data.csv')
print(data.head())

# Display summary statistics
print(data.describe())

# Visualize data distributions
data.hist(bins=20, figsize=(10, 8))
plt.tight_layout()
plt.show()
# Out:
#    week  sets  reps  rpe  base_weight  predicted_1rm
# 0     7     4     7  9.2          138          177.4
# 1     4     4     7  7.0          173          195.4
# 2    11     4     3  8.4          188          226.6
# 3     8     3     3  7.9          117          145.6
# 4     5     4     7  9.6          118          155.4
#              week        sets      reps         rpe  base_weight  \
# count  500.000000  500.000000  500.0000  500.000000   500.000000
# mean     6.504000    3.936000    4.9700    8.533200   146.626000
# std      3.543317    0.820518    1.4287    0.868866    29.532804
# min      1.000000    3.000000    3.0000    7.000000   100.000000
# 25%      3.000000    3.000000    4.0000    7.800000   120.000000
# 50%      7.000000    4.000000    5.0000    8.600000   143.000000
# 75%     10.000000    5.000000    6.0000    9.300000   172.250000
# max     12.000000    5.000000    7.0000   10.000000   199.000000
#
#        predicted_1rm
# count     500.000000
# mean      179.168000
# std        30.778814
# min       118.500000
# 25%       153.175000
# 50%       176.150000
# 75%       205.950000
# max       246.500000

# %%
from src import model
import datetime

# Create a log directory for TensorBoard
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model (using your preprocessed data)
history = model.fit(
    X_train, 
    y_train, 
    epochs=50, 
    batch_size=16, 
    validation_split=0.2,
    callbacks=[tensorboard_callback]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 9
#       6 tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
#       8 # Train the model (using your preprocessed data)
# ----> 9 history = model.fit(
#      10     X_train,
#      11     y_train,
#      12     epochs=50,
#      13     batch_size=16,
#      14     validation_split=0.2,
#      15     callbacks=[tensorboard_callback]
#      16 )
#
# AttributeError: module 'src.model' has no attribute 'fit'

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-d9181f356d49e104" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d9181f356d49e104");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import datetime
import tensorflow as tf
from src.data_preprocessing import load_and_preprocess_data
from src.model import build_model

# Load data and build the model
X_train, X_test, y_train, y_test, scaler = load_and_preprocess_data()
model = build_model((X_train.shape[1],))

# Create a log directory for TensorBoard logs
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model with the TensorBoard callback
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[tensorboard_callback]
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import datetime
#       2 import tensorflow as tf
# ----> 3 from src.data_preprocessing import load_and_preprocess_data
#       4 from src.model import build_model
#       6 # Load data and build the model
#
# File ~\PycharmProjects\deadlift_predictive\src\data_preprocessing.py:4
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.preprocessing import StandardScaler
# ----> 4 from model import build_model
#       5 import tensorflow as tf
#       8 # load_and_preprocess_data function with updated file path
#
# ModuleNotFoundError: No module named 'model'

# %%
import datetime
import tensorflow as tf
from src.data_preprocessing import load_and_preprocess_data
from src/model.py import build_model

# Load data and build the model
X_train, X_test, y_train, y_test, scaler = load_and_preprocess_data()
model = build_model((X_train.shape[1],))

# Create a log directory for TensorBoard logs
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model with the TensorBoard callback
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[tensorboard_callback]
)
# Out:
#   Cell In[20], line 4
#     from src/model.py import build_model
#             ^
# SyntaxError: invalid syntax

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 7292), started 0:19:32 ago. (Use '!kill 7292' to kill it.)
#       <iframe id="tensorboard-frame-5eeb6c2c20643b95" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5eeb6c2c20643b95");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import datetime
import tensorflow as tf
from src.data_preprocessing import load_and_preprocess_data
from src.model import build_model

# Load data and build the model
X_train, X_test, y_train, y_test, scaler = load_and_preprocess_data()
model = build_model((X_train.shape[1],))

# Create a log directory for TensorBoard logs
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model with the TensorBoard callback
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[tensorboard_callback]
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 import datetime
#       2 import tensorflow as tf
# ----> 3 from src.data_preprocessing import load_and_preprocess_data
#       4 from src.model import build_model
#       6 # Load data and build the model
#
# File ~\PycharmProjects\deadlift_predictive\src\data_preprocessing.py:4
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.preprocessing import StandardScaler
# ----> 4 from model import build_model
#       5 import tensorflow as tf
#       8 # load_and_preprocess_data function with updated file path
#
# ModuleNotFoundError: No module named 'model'

# %%
import datetime
import tensorflow as tf
from src.data_preprocessing import load_and_preprocess_data
from src.model.py import build_model

# Load data and build the model
X_train, X_test, y_train, y_test, scaler = load_and_preprocess_data()
model = build_model((X_train.shape[1],))

# Create a log directory for TensorBoard logs
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model with the TensorBoard callback
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[tensorboard_callback]
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 3
#       1 import datetime
#       2 import tensorflow as tf
# ----> 3 from src.data_preprocessing import load_and_preprocess_data
#       4 from src.model.py import build_model
#       6 # Load data and build the model
#
# File ~\PycharmProjects\deadlift_predictive\src\data_preprocessing.py:4
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.preprocessing import StandardScaler
# ----> 4 from model import build_model
#       5 import tensorflow as tf
#       8 # load_and_preprocess_data function with updated file path
#
# ModuleNotFoundError: No module named 'model'

# %%
import sys

sys.path.append("C:/Users/skard/PycharmProjects/deadlift_predictive/src")

# Now you should be able to import from model.py
from model import build_model

# %%
import datetime
import tensorflow as tf
import sys

sys.path.append("C:/Users/skard/PycharmProjects/deadlift_predictive/")

from src.data_preprocessing import load_and_preprocess_data
from src.model import build_model

# Load data and build the model
X_train, X_test, y_train, y_test, scaler = load_and_preprocess_data()
model = build_model((X_train.shape[1],))

# Create a log directory for TensorBoard logs
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model with the TensorBoard callback
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[tensorboard_callback]
)
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 34047.5586 - mae: 181.9033 - val_loss: 31972.3125 - val_mae: 176.2602
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33004.3906 - mae: 179.2494 - val_loss: 31409.7461 - val_mae: 174.6136
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32384.7910 - mae: 177.2019 - val_loss: 30451.9785 - val_mae: 171.7754
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30590.8809 - mae: 171.8574 - val_loss: 28962.8320 - val_mae: 167.2921
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29238.3770 - mae: 167.7320 - val_loss: 26842.1836 - val_mae: 160.7255
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26139.2324 - mae: 158.3737 - val_loss: 24035.8320 - val_mae: 151.6155
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24165.4492 - mae: 151.7988 - val_loss: 20531.0039 - val_mae: 139.4716
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20351.5039 - mae: 137.9975 - val_loss: 16528.1309 - val_mae: 124.2094
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15473.9277 - mae: 119.9986 - val_loss: 12350.7891 - val_mae: 106.1267
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10337.6035 - mae: 96.1867 - val_loss: 8450.0508 - val_mae: 86.0916
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6931.8013 - mae: 77.0019 - val_loss: 5234.9307 - val_mae: 66.3734
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3829.0320 - mae: 55.4217 - val_loss: 3018.8047 - val_mae: 49.2520
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 